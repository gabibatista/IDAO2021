# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# imports

from google.colab import files
from os import listdir
from os.path import isfile, join
import re
from collections import Counter
from PIL import Image
import numpy as np
from keras.models import Model
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, MaxPooling2D, Dropout
#summary e plot_model
#from keras.utils import plot_model, summary
from matplotlib.image import imread
from random import shuffle
from math import ceil

# %%
# variaveis

img_to_load = 300 # imagens a serem carregadas por vez (carregando as 10000 de uma vez sobrecarrega o sistema)
crop_size = 150 # altura e largura da imagem a ser enviada para o modelo
train = 0.9 # porcentagem de dados a ser usado para treino

# %%
#função para pegar só o centro da imagem

def crop_center(img,cropx,cropy):
    y,x = img.shape
    startx = x//2-(cropx//2)
    starty = y//2-(cropy//2)    
    return img[starty:starty+cropy,startx:startx+cropx]

# %%
#carregar nome de todas as imagens

ER_path = '/gdrive/My Drive/IDAO/train/ER/'
ER_files = [f'/gdrive/My Drive/IDAO/train/ER/{f}' for f in listdir(ER_path) if isfile(join(ER_path, f))]

NR_path = '/gdrive/My Drive/IDAO/train/NR/'
NR_files = [f'/gdrive/My Drive/IDAO/train/NR/{f}' for f in listdir(NR_path) if isfile(join(NR_path, f))]

all_files = ER_files + NR_files
shuffle(all_files)

# %%
# criar um dicionário para armazenar todos os dados separadamente
# isso é necessário para garantir que 70% de cada uma das classes serão usadas para treino

images = {'NR_1_keV': [], 'NR_6_keV': [], 'NR_20_keV': [], 'ER_3_keV': [], 'ER_10_keV': [], 'ER_30_keV': []}

# %%
# coloca todas as strings das imagens no dicionário

for particle_type in images.keys():
  images[particle_type] = [img for img in all_files if particle_type in img]

for x in images.keys():
    images[x] = images[x]
    print(f"{x}: {len(images[x])}")
# Out:
# NR_1_keV: 2177
# NR_6_keV: 2255
# NR_20_keV: 2208
# ER_3_keV: 2243
# ER_10_keV: 2272
# ER_30_keV: 2237

# %%
# carrega 70% dos dados no X_train e 30% no X_test

X_train = []
X_test = []

for particle_type in images.keys():
    X_train = X_train + images[particle_type][:int(train*len(images[particle_type]))]
    X_test = X_test + images[particle_type][int(train*len(images[particle_type])):]
shuffle(X_train)
shuffle(X_test)

# %%
# cria o Y_train e Y_test com base no X_train e X_test criado anteriormente

Y_train = [int(re.findall(r"\d+(?=_keV)", en)[0])/30.0 for en in X_train]
Y_test = [int(re.findall(r"\d+(?=_keV)", en)[0])/30.0 for en in X_test]

# teste sem dividir por 30
Y_train = [int(re.findall(r"\d+(?=_keV)", en)[0]) for en in X_train]
Y_test = [int(re.findall(r"\d+(?=_keV)", en)[0]) for en in X_test]

print(X_train[:10])
print(Y_train[:10])
print(X_test[:10])
print(Y_test[:10])
print(len(X_test))
print(len(Y_test))
# Out:
# ['/gdrive/My Drive/IDAO/train/ER/0.2464424967765808__CYGNO_60_40_ER_3_keV_930V_30cm_IDAO_iso_crop_hist_pic_run2_ev167;1.png', '/gdrive/My Drive/IDAO/train/ER/-1.283082365989685__CYGNO_60_40_ER_3_keV_930V_30cm_IDAO_iso_crop_hist_pic_run5_ev221;1.png', '/gdrive/My Drive/IDAO/train/ER/-0.7183917164802551__CYGNO_60_40_ER_30_keV_930V_30cm_IDAO_iso_crop_hist_pic_run5_ev255;1.png', '/gdrive/My Drive/IDAO/train/NR/0.07020000368356705__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev252;1.png', '/gdrive/My Drive/IDAO/train/ER/1.2236688137054443__CYGNO_60_40_ER_3_keV_930V_30cm_IDAO_iso_crop_hist_pic_run2_ev583;1.png', '/gdrive/My Drive/IDAO/train/NR/2.1810998916625977__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev980;1.png', '/gdrive/My Drive/IDAO/train/NR/0.2946000099182129__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run5_ev731;1.png', '/gdrive/My Drive/IDAO/train/ER/-1.3905295133590698__CYGNO_60_40_ER_3_keV_930V_30cm_IDAO_iso_crop_hist_pic_run2_ev278;1.png', '/gdrive/My Drive/IDAO/train/NR/-0.8009999990463257__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run1_ev850;1.png', '/gdrive/My Drive/IDAO/train/NR/-0.5903000235557556__CYGNO_60_40_He_NR_1_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev858;1.png']
# [3, 3, 30, 6, 3, 6, 20, 3, 6, 1]
# ['/gdrive/My Drive/IDAO/train/ER/0.41408175230026245__CYGNO_60_40_ER_3_keV_930V_30cm_IDAO_iso_crop_hist_pic_run3_ev154;1.png', '/gdrive/My Drive/IDAO/train/ER/-0.5588486790657043__CYGNO_60_40_ER_3_keV_930V_30cm_IDAO_iso_crop_hist_pic_run1_ev634;1.png', '/gdrive/My Drive/IDAO/train/NR/2.9235999584198__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev403;1.png', '/gdrive/My Drive/IDAO/train/NR/1.6790000200271606__CYGNO_60_40_He_NR_20_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run4_ev595;1.png', '/gdrive/My Drive/IDAO/train/NR/-2.088200092315674__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run2_ev121;1.png', '/gdrive/My Drive/IDAO/train/ER/1.361674189567566__CYGNO_60_40_ER_10_keV_930V_30cm_IDAO_iso_crop_hist_pic_run1_ev622;1.png', '/gdrive/My Drive/IDAO/train/ER/0.7498147487640381__CYGNO_60_40_ER_3_keV_930V_30cm_IDAO_iso_crop_hist_pic_run2_ev603;1.png', '/gdrive/My Drive/IDAO/train/ER/-1.400260090827942__CYGNO_60_40_ER_3_keV_930V_30cm_IDAO_iso_crop_hist_pic_run3_ev352;1.png', '/gdrive/My Drive/IDAO/train/ER/1.1402039527893066__CYGNO_60_40_ER_10_keV_930V_30cm_IDAO_iso_crop_hist_pic_run5_ev416;1.png', '/gdrive/My Drive/IDAO/train/NR/-0.35569998621940613__CYGNO_60_40_He_NR_6_keV_930V_30cm_SRIM_IDAO_iso_crop_hist_pic_run3_ev129;1.png']
# [3, 3, 6, 20, 6, 10, 3, 3, 10, 6]
# 1342
# 1342

# %%
# first model test

test_model = Sequential()

test_model.add(Conv2D(32, (3, 3), input_shape=(crop_size, crop_size, 1)))
test_model.add(Activation('relu'))
test_model.add(MaxPooling2D(pool_size=(2, 2)))

test_model.add(Conv2D(32, (3, 3)))
test_model.add(Activation('relu'))
test_model.add(MaxPooling2D(pool_size=(2, 2)))

test_model.add(Conv2D(64, (3, 3)))
test_model.add(Activation('relu'))
test_model.add(MaxPooling2D(pool_size=(2, 2)))

test_model.add(Flatten())

test_model.add(Dense(512, activation='relu'))
#test_model.add(Dropout(0.1))

test_model.add(Dense(256, activation='relu'))
test_model.add(Dense(128, activation='relu'))

test_model.add(Dense(64))
test_model.add(Activation('relu'))
#test_model.add(Dropout(0.5)) # treinar dpois com o dropout
test_model.add(Dense(1))
test_model.add(Activation('linear'))

test_model.compile(loss='mean_absolute_error',
              optimizer='adam', #rmsprop
              metrics=['mean_squared_error']) #MSE

# %%
# second model test

second_model = Sequential()

second_model.add(Conv2D(32, (3, 3), input_shape=(crop_size, crop_size, 1)))
second_model.add(Activation('relu'))
second_model.add(MaxPooling2D(pool_size=(2, 2)))

second_model.add(Conv2D(64, (3, 3)))
second_model.add(Activation('relu'))
second_model.add(MaxPooling2D(pool_size=(2, 2)))

second_model.add(Conv2D(128, (3, 3)))
second_model.add(Activation('relu'))
second_model.add(MaxPooling2D(pool_size=(2, 2)))

second_model.add(Flatten())

#second_model.add(Dropout(0.1))

second_model.add(Dense(64))
second_model.add(Activation('relu'))
#second_model.add(Dropout(0.5)) # treinar dpois com o dropout
second_model.add(Dense(1))
second_model.add(Activation('linear'))

second_model.compile(loss='mean_absolute_error',
              optimizer='rmsprop', #rmsprop
              metrics=['accuracy'])

# %%
# third model test

third_model = Sequential()

third_model.add(Conv2D(32, (3, 3), input_shape=(crop_size, crop_size, 1)))
third_model.add(Activation('relu'))
third_model.add(MaxPooling2D(pool_size=(2, 2)))

third_model.add(Conv2D(64, (3, 3)))
third_model.add(Activation('relu'))
third_model.add(MaxPooling2D(pool_size=(2, 2)))

third_model.add(Conv2D(64, (3, 3)))
third_model.add(Activation('relu'))
third_model.add(MaxPooling2D(pool_size=(2, 2)))

third_model.add(Conv2D(128, (3, 3)))
third_model.add(Activation('relu'))
third_model.add(MaxPooling2D(pool_size=(2, 2)))

third_model.add(Flatten())

#third_model.add(Dropout(0.1))

test_model.add(Dense(128, activation='relu'))
third_model.add(Dense(64))
third_model.add(Activation('relu'))
#third_model.add(Dropout(0.5)) # treinar dpois com o dropout
third_model.add(Dense(1))
third_model.add(Activation('linear'))

third_model.compile(loss='mean_absolute_error',
              optimizer='rmsprop', #rmsprop
              metrics=['accuracy'])

# %%
# fourth model test

fourth_model = Sequential()

fourth_model.add(Conv2D(32, (3, 3), input_shape=(crop_size, crop_size, 1)))
fourth_model.add(Activation('relu'))

fourth_model.add(Conv2D(64, (3, 3)))
fourth_model.add(Activation('relu'))
fourth_model.add(MaxPooling2D(pool_size=(2, 2)))

fourth_model.add(Conv2D(64, (3, 3)))
fourth_model.add(Activation('relu'))
fourth_model.add(MaxPooling2D(pool_size=(2, 2)))

fourth_model.add(Flatten())

#fourth_model.add(Dropout(0.1))

test_model.add(Dense(128, activation='relu'))
fourth_model.add(Dense(64))
fourth_model.add(Activation('relu'))
#fourth_model.add(Dropout(0.5)) # treinar dpois com o dropout
fourth_model.add(Dense(1))
fourth_model.add(Activation('linear'))

fourth_model.compile(loss='mean_absolute_error',
              optimizer='adam', #rmsprop
              metrics=['accuracy'])

# %%
# treina o modelo usando batches de 300 imagens por vez

for i in range(ceil(len(X_train)/img_to_load)):
#for i in range(ceil(1500/img_to_load)):
    begin = i*img_to_load
    limit = min(i*img_to_load + img_to_load, len(X_train))
    if begin == limit:
        break

    X_train_img = [crop_center(imread(file), crop_size, crop_size) for file in X_train[begin:limit]]
    Y_train_img = Y_train[begin:limit]
    print(f'loaded {begin} to {limit}')

    X_train_img = np.stack(X_train_img, axis=0)
    X_train_img = X_train_img.reshape((X_train_img.shape + (1,)))
    Y_train_img = np.stack(Y_train_img, axis=0).reshape((len(Y_train_img), 1))
    #print(X_train_img.shape)
    test_model.fit(X_train_img, Y_train_img, epochs=10, batch_size=50)
# Out:
# loaded 0 to 300
# Epoch 1/10
# 6/6 [==============================] - 1s 34ms/step - loss: 11.4004 - accuracy: 0.0000e+00
# Epoch 2/10
# 6/6 [==============================] - 0s 27ms/step - loss: 10.2936 - accuracy: 0.0000e+00
# Epoch 3/10
# 6/6 [==============================] - 0s 24ms/step - loss: 10.3363 - accuracy: 0.0000e+00
# Epoch 4/10
# 6/6 [==============================] - 0s 25ms/step - loss: 9.9718 - accuracy: 0.0000e+00
# Epoch 5/10
# 6/6 [==============================] - 0s 24ms/step - loss: 10.0440 - accuracy: 0.0000e+00
# Epoch 6/10
# 6/6 [==============================] - 0s 25ms/step - loss: 10.2455 - accuracy: 0.0000e+00
# Epoch 7/10
# 6/6 [==============================] - 0s 24ms/step - loss: 9.6392 - accuracy: 0.0000e+00
# Epoch 8/10
# 6/6 [==============================] - 0s 24ms/step - loss: 9.8368 - accuracy: 0.0000e+00
# Epoch 9/10
# 6/6 [==============================] - 0s 26ms/step - loss: 9.7282 - accuracy: 0.0000e+00
# Epoch 10/10
# 6/6 [==============================] - 0s 25ms/step - loss: 10.3288 - accuracy: 0.0000e+00
# loaded 300 to 600
# Epoch 1/10
# 6/6 [==============================] - 0s 34ms/step - loss: 9.7431 - accuracy: 0.0633
# Epoch 2/10
# 6/6 [==============================] - 0s 26ms/step - loss: 9.6768 - accuracy: 0.1733
# Epoch 3/10
# 6/6 [==============================] - 0s 25ms/step - loss: 9.6387 - accuracy: 0.1733
# Epoch 4/10
# 6/6 [==============================] - 0s 24ms/step - loss: 9.6391 - accuracy: 0.0533
# Epoch 5/10
# 6/6 [==============================] - 0s 25ms/step - loss: 9.6481 - accuracy: 0.0000e+00
# Epoch 6/10
# 6/6 [==============================] - 0s 25ms/step - loss: 9.6441 - accuracy: 0.0000e+00
# Epoch 7/10
# 6/6 [==============================] - 0s 25ms/step - loss: 9.6602 - accuracy: 0.0000e+00
# Epoch 8/10
# 6/6 [==============================] - 0s 25ms/step - loss: 9.6310 - accuracy: 0.0000e+00
# Epoch 9/10
# 6/6 [==============================] - 0s 25ms/step - loss: 9.6442 - accuracy: 0.0000e+00
# Epoch 10/10
# 6/6 [==============================] - 0s 24ms/step - loss: 9.6442 - accuracy: 0.1600
# loaded 600 to 900
# Epoch 1/10
# 6/6 [==============================] - 0s 35ms/step - loss: 9.6398 - accuracy: 0.1600
# Epoch 2/10
# 6/6 [==============================] - 0s 26ms/step - loss: 9.6469 - accuracy: 0.1600
# Epoch 3/10
# 6/6 [==============================]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-26277aa385da> in <module>()
#      16     Y_train_img = np.stack(Y_train_img, axis=0).reshape((len(Y_train_img), 1))
#      17     #print(X_train_img.shape)
# ---> 18     test_model.fit(X_train_img, Y_train_img, epochs=10, batch_size=50)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1143           epoch_logs.update(val_logs)
#    1144
# -> 1145         callbacks.on_epoch_end(epoch, epoch_logs)
#    1146         training_logs = epoch_logs
#    1147         if self.stop_training:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     426     for callback in self.callbacks:
#     427       if getattr(callback, '_supports_tf_logs', False):
# --> 428         callback.on_epoch_end(epoch, logs)
#     429       else:
#     430         if numpy_logs is None:  # Only convert once.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#    1029
#    1030   def on_epoch_end(self, epoch, logs=None):
# -> 1031     self._finalize_progbar(logs, self._train_step)
#    1032
#    1033   def on_test_end(self, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in _finalize_progbar(self, logs, counter)
#    1094       self.target = counter or self.seen
#    1095       self.progbar.target = self.target
# -> 1096     self.progbar.update(self.target, list(logs.items()), finalize=True)
#    1097
#    1098
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     623         info += ' - %s:' % k
#     624         if isinstance(self._values[k], list):
# --> 625           avg = np.mean(self._values[k][0] / max(1, self._values[k][1]))
#     626           if abs(avg) > 1e-3:
#     627             info += ' %.4f' % avg
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3371
#    3372     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 3373                           out=out, **kwargs)
#    3374
#    3375
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#     158             is_float16_result = True
#     159
# --> 160     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     161     if isinstance(ret, mu.ndarray):
#     162         ret = um.true_divide(
#
# KeyboardInterrupt:

# %%
# treina o modelo usando batches de 300 imagens por vez

for i in range(ceil(len(X_train)/img_to_load)):
#for i in range(ceil(1500/img_to_load)):
    begin = i*img_to_load
    limit = min(i*img_to_load + img_to_load, len(X_train))
    if begin == limit:
        break

    X_train_img = [crop_center(imread(file), crop_size, crop_size) for file in X_train[begin:limit]]
    Y_train_img = Y_train[begin:limit]
    print(f'loaded {begin} to {limit}')

    X_train_img = np.stack(X_train_img, axis=0)
    X_train_img = X_train_img.reshape((X_train_img.shape + (1,)))
    Y_train_img = np.stack(Y_train_img, axis=0).reshape((len(Y_train_img), 1))
    #print(X_train_img.shape)
    second_model.fit(X_train_img, Y_train_img, epochs=10, batch_size=50)
    third_model.fit(X_train_img, Y_train_img, epochs=10, batch_size=50)
    fourth_model.fit(X_train_img, Y_train_img, epochs=10, batch_size=50)
# Out:
# loaded 0 to 300
# Epoch 1/10
# 6/6 [==============================] - 1s 40ms/step - loss: 9.5211 - accuracy: 0.1133
# Epoch 2/10
# 6/6 [==============================] - 0s 33ms/step - loss: 8.3650 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 7.4757 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 7.4319 - accuracy: 0.1500
# Epoch 5/10
# 6/6 [==============================] - 0s 32ms/step - loss: 7.3625 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 6.9896 - accuracy: 0.1500
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 6.6902 - accuracy: 0.1500
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 6.4571 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 5.5404 - accuracy: 0.1500
# Epoch 10/10
# 6/6 [==============================] - 0s 31ms/step - loss: 5.5065 - accuracy: 0.1500
# Epoch 1/10
# 6/6 [==============================] - 1s 29ms/step - loss: 10.7358 - accuracy: 0.0600
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 7.8433 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 6.2601 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 5.3702 - accuracy: 0.1500
# Epoch 5/10
# 6/6 [==============================] - 0s 29ms/step - loss: 4.5026 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 3.7939 - accuracy: 0.1500
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 3.2672 - accuracy: 0.1500
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.6851 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 31ms/step - loss: 3.1786 - accuracy: 0.1500
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 3.0571 - accuracy: 0.1500
# Epoch 1/10
# 6/6 [==============================] - 1s 63ms/step - loss: 10.5534 - accuracy: 0.0367
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.8296 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 64ms/step - loss: 9.0130 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 64ms/step - loss: 8.3373 - accuracy: 0.1500
# Epoch 5/10
# 6/6 [==============================] - 0s 63ms/step - loss: 7.1184 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 6.4085 - accuracy: 0.1500
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 5.8723 - accuracy: 0.1500
# Epoch 8/10
# 6/6 [==============================] - 0s 63ms/step - loss: 5.3426 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 63ms/step - loss: 4.4160 - accuracy: 0.1500
# Epoch 10/10
# 6/6 [==============================] - 0s 62ms/step - loss: 4.3102 - accuracy: 0.1500
# loaded 300 to 600
# Epoch 1/10
# 6/6 [==============================] - 0s 43ms/step - loss: 5.5950 - accuracy: 0.1133
# Epoch 2/10
# 6/6 [==============================] - 0s 32ms/step - loss: 4.8732 - accuracy: 0.1333
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 4.3676 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 4.5077 - accuracy: 0.1333
# Epoch 5/10
# 6/6 [==============================] - 0s 32ms/step - loss: 4.0739 - accuracy: 0.1467
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 3.6967 - accuracy: 0.1200
# Epoch 7/10
# 6/6 [==============================] - 0s 32ms/step - loss: 3.4918 - accuracy: 0.1300
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 3.8472 - accuracy: 0.1200
# Epoch 9/10
# 6/6 [==============================] - 0s 31ms/step - loss: 3.2298 - accuracy: 0.1200
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.7603 - accuracy: 0.1300
# Epoch 1/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.2737 - accuracy: 0.1500
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.1804 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.3295 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.0731 - accuracy: 0.1500
# Epoch 5/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.3663 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.7740 - accuracy: 0.1500
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8876 - accuracy: 0.1500
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.6422 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.1814 - accuracy: 0.1500
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.2015 - accuracy: 0.1500
# Epoch 1/10
# 6/6 [==============================] - 0s 62ms/step - loss: 3.9795 - accuracy: 0.1500
# Epoch 2/10
# 6/6 [==============================] - 0s 62ms/step - loss: 3.9724 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 63ms/step - loss: 3.6945 - accuracy: 0.1200
# Epoch 4/10
# 6/6 [==============================] - 0s 63ms/step - loss: 3.3474 - accuracy: 0.1400
# Epoch 5/10
# 6/6 [==============================] - 0s 63ms/step - loss: 3.3867 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 3.2025 - accuracy: 0.1500
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.8346 - accuracy: 0.1333
# Epoch 8/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.6909 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 62ms/step - loss: 2.4066 - accuracy: 0.1500
# Epoch 10/10
# 6/6 [==============================] - 0s 62ms/step - loss: 2.2724 - accuracy: 0.1467
# loaded 600 to 900
# Epoch 1/10
# 6/6 [==============================] - 0s 45ms/step - loss: 3.2827 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 33ms/step - loss: 3.8410 - accuracy: 0.1400
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.8089 - accuracy: 0.1133
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 3.3654 - accuracy: 0.1567
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 2.4704 - accuracy: 0.1433
# Epoch 6/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.2913 - accuracy: 0.1267
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 2.5328 - accuracy: 0.1400
# Epoch 8/10
# 6/6 [==============================] - 0s 33ms/step - loss: 2.3838 - accuracy: 0.1200
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.0655 - accuracy: 0.1467
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.9440 - accuracy: 0.1233
# Epoch 1/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.1754 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 29ms/step - loss: 1.7970 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8496 - accuracy: 0.1567
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.1861 - accuracy: 0.1567
# Epoch 5/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.9279 - accuracy: 0.1533
# Epoch 6/10
# 6/6 [==============================] - 0s 29ms/step - loss: 1.6362 - accuracy: 0.1533
# Epoch 7/10
# 6/6 [==============================] - 0s 31ms/step - loss: 2.1737 - accuracy: 0.1567
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.6465 - accuracy: 0.1567
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.5154 - accuracy: 0.1567
# Epoch 10/10
# 6/6 [==============================] - 0s 29ms/step - loss: 1.4081 - accuracy: 0.1567
# Epoch 1/10
# 6/6 [==============================] - 0s 64ms/step - loss: 3.0821 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 62ms/step - loss: 3.3078 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 63ms/step - loss: 3.0208 - accuracy: 0.1400
# Epoch 4/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.9411 - accuracy: 0.1467
# Epoch 5/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.6923 - accuracy: 0.1567
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.6451 - accuracy: 0.1533
# Epoch 7/10
# 6/6 [==============================] - 0s 62ms/step - loss: 2.4673 - accuracy: 0.1567
# Epoch 8/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.6380 - accuracy: 0.1567
# Epoch 9/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.3842 - accuracy: 0.1567
# Epoch 10/10
# 6/6 [==============================] - 0s 62ms/step - loss: 2.3088 - accuracy: 0.1567
# loaded 900 to 1200
# Epoch 1/10
# 6/6 [==============================] - 0s 44ms/step - loss: 2.7171 - accuracy: 0.1333
# Epoch 2/10
# 6/6 [==============================] - 0s 33ms/step - loss: 2.0956 - accuracy: 0.1467
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.0318 - accuracy: 0.1533
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.2774 - accuracy: 0.1467
# Epoch 5/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.8389 - accuracy: 0.1467
# Epoch 6/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.5013 - accuracy: 0.1533
# Epoch 7/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.4290 - accuracy: 0.1500
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.6988 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.1063 - accuracy: 0.1400
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.3456 - accuracy: 0.1533
# Epoch 1/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.4893 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.6312 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.8904 - accuracy: 0.1567
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.5559 - accuracy: 0.1567
# Epoch 5/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.8062 - accuracy: 0.1567
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.9558 - accuracy: 0.1567
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8353 - accuracy: 0.1567
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3375 - accuracy: 0.1567
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3968 - accuracy: 0.1567
# Epoch 10/10
# 6/6 [==============================] - 0s 29ms/step - loss: 2.0263 - accuracy: 0.1500
# Epoch 1/10
# 6/6 [==============================] - 0s 64ms/step - loss: 2.3870 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.2624 - accuracy: 0.1533
# Epoch 3/10
# 6/6 [==============================] - 0s 64ms/step - loss: 2.1489 - accuracy: 0.1567
# Epoch 4/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.3001 - accuracy: 0.1167
# Epoch 5/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.1354 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.9836 - accuracy: 0.1533
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.9702 - accuracy: 0.1500
# Epoch 8/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.8783 - accuracy: 0.1567
# Epoch 9/10
# 6/6 [==============================] - 0s 62ms/step - loss: 1.9028 - accuracy: 0.1533
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.7850 - accuracy: 0.1433
# loaded 1200 to 1500
# Epoch 1/10
# 6/6 [==============================] - 0s 40ms/step - loss: 7.6545 - accuracy: 0.1467
# Epoch 2/10
# 6/6 [==============================] - 0s 34ms/step - loss: 2.0545 - accuracy: 0.1367
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.8370 - accuracy: 0.1400
# Epoch 4/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.6586 - accuracy: 0.1467
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.5624 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.6982 - accuracy: 0.1600
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.7353 - accuracy: 0.1533
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.7137 - accuracy: 0.1300
# Epoch 9/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.7716 - accuracy: 0.1500
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.4252 - accuracy: 0.1500
# Epoch 1/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8310 - accuracy: 0.1433
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.7734 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.6653 - accuracy: 0.1467
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3880 - accuracy: 0.1567
# Epoch 5/10
# 6/6 [==============================] - 0s 31ms/step - loss: 2.1267 - accuracy: 0.1633
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8838 - accuracy: 0.1233
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.4119 - accuracy: 0.1600
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.4364 - accuracy: 0.1633
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.0635 - accuracy: 0.1633
# Epoch 10/10
# 6/6 [==============================] - 0s 29ms/step - loss: 1.5548 - accuracy: 0.1467
# Epoch 1/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.5846 - accuracy: 0.1500
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.4832 - accuracy: 0.1633
# Epoch 3/10
# 6/6 [==============================] - 0s 64ms/step - loss: 2.3966 - accuracy: 0.1633
# Epoch 4/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.2625 - accuracy: 0.1600
# Epoch 5/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.1783 - accuracy: 0.1633
# Epoch 6/10
# 6/6 [==============================] - 0s 62ms/step - loss: 2.3956 - accuracy: 0.1467
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 5.1848 - accuracy: 0.1600
# Epoch 8/10
# 6/6 [==============================] - 0s 62ms/step - loss: 4.5693 - accuracy: 0.1633
# Epoch 9/10
# 6/6 [==============================] - 0s 63ms/step - loss: 3.5224 - accuracy: 0.1600
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 3.0115 - accuracy: 0.1633
# loaded 1500 to 1800
# Epoch 1/10
# 6/6 [==============================] - 0s 41ms/step - loss: 2.0664 - accuracy: 0.1200
# Epoch 2/10
# 6/6 [==============================] - 0s 34ms/step - loss: 2.9503 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.9387 - accuracy: 0.1367
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.2232 - accuracy: 0.1200
# Epoch 5/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.7325 - accuracy: 0.1367
# Epoch 6/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.6889 - accuracy: 0.1467
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 2.2486 - accuracy: 0.1233
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.1422 - accuracy: 0.1300
# Epoch 9/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.4575 - accuracy: 0.1467
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.8395 - accuracy: 0.1433
# Epoch 1/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.9216 - accuracy: 0.1500
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.9298 - accuracy: 0.1467
# Epoch 3/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.9442 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.9045 - accuracy: 0.1433
# Epoch 5/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.6091 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.6269 - accuracy: 0.1500
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.3831 - accuracy: 0.1133
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.4699 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.4860 - accuracy: 0.1500
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.4209 - accuracy: 0.1500
# Epoch 1/10
# 6/6 [==============================] - 0s 66ms/step - loss: 3.2866 - accuracy: 0.1500
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 3.0840 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 63ms/step - loss: 3.0110 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 64ms/step - loss: 2.6103 - accuracy: 0.1500
# Epoch 5/10
# 6/6 [==============================] - 0s 62ms/step - loss: 2.6207 - accuracy: 0.1133
# Epoch 6/10
# 6/6 [==============================] - 0s 64ms/step - loss: 2.2991 - accuracy: 0.1233
# Epoch 7/10
# 6/6 [==============================] - 0s 62ms/step - loss: 2.3399 - accuracy: 0.1500
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 2.2850 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 65ms/step - loss: 2.1072 - accuracy: 0.1233
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.0810 - accuracy: 0.1400
# loaded 1800 to 2100
# Epoch 1/10
# 6/6 [==============================] - 0s 41ms/step - loss: 1.7383 - accuracy: 0.1300
# Epoch 2/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.7886 - accuracy: 0.1167
# Epoch 3/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.7614 - accuracy: 0.1233
# Epoch 4/10
# 6/6 [==============================] - 0s 34ms/step - loss: 2.0894 - accuracy: 0.0967
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.5634 - accuracy: 0.1400
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 2.6683 - accuracy: 0.1433
# Epoch 7/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.4869 - accuracy: 0.1467
# Epoch 8/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.5610 - accuracy: 0.1133
# Epoch 9/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3689 - accuracy: 0.1433
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.4121 - accuracy: 0.1367
# Epoch 1/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.1994 - accuracy: 0.1467
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.0684 - accuracy: 0.1467
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.7301 - accuracy: 0.1433
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8194 - accuracy: 0.1333
# Epoch 5/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8992 - accuracy: 0.1267
# Epoch 6/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.5068 - accuracy: 0.1467
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8813 - accuracy: 0.1300
# Epoch 8/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.5608 - accuracy: 0.1467
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.5533 - accuracy: 0.1467
# Epoch 10/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.5821 - accuracy: 0.1367
# Epoch 1/10
# 6/6 [==============================] - 0s 64ms/step - loss: 2.5361 - accuracy: 0.1233
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 2.4086 - accuracy: 0.1433
# Epoch 3/10
# 6/6 [==============================] - 0s 65ms/step - loss: 2.1842 - accuracy: 0.1467
# Epoch 4/10
# 6/6 [==============================] - 0s 62ms/step - loss: 2.1224 - accuracy: 0.1433
# Epoch 5/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.9870 - accuracy: 0.1400
# Epoch 6/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.8798 - accuracy: 0.1467
# Epoch 7/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.8454 - accuracy: 0.1433
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 2.0013 - accuracy: 0.1467
# Epoch 9/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.7272 - accuracy: 0.1333
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.5629 - accuracy: 0.1367
# loaded 2100 to 2400
# Epoch 1/10
# 6/6 [==============================] - 0s 42ms/step - loss: 1.4498 - accuracy: 0.1867
# Epoch 2/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3971 - accuracy: 0.1767
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.3255 - accuracy: 0.1633
# Epoch 4/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.5958 - accuracy: 0.1500
# Epoch 5/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.0955 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0942 - accuracy: 0.1900
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.5620 - accuracy: 0.1267
# Epoch 8/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.3284 - accuracy: 0.1700
# Epoch 9/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.9442 - accuracy: 0.1967
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0703 - accuracy: 0.1733
# Epoch 1/10
# 6/6 [==============================] - 0s 29ms/step - loss: 1.4118 - accuracy: 0.1733
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3528 - accuracy: 0.1867
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.8053 - accuracy: 0.1967
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3864 - accuracy: 0.1833
# Epoch 5/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.0663 - accuracy: 0.1933
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.5597 - accuracy: 0.1933
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.0740 - accuracy: 0.1967
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.6995 - accuracy: 0.1800
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.1742 - accuracy: 0.1700
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.0422 - accuracy: 0.1967
# Epoch 1/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.8011 - accuracy: 0.1967
# Epoch 2/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.7918 - accuracy: 0.1767
# Epoch 3/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.6479 - accuracy: 0.1367
# Epoch 4/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.5247 - accuracy: 0.1633
# Epoch 5/10
# 6/6 [==============================] - 0s 66ms/step - loss: 1.4185 - accuracy: 0.1933
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.3630 - accuracy: 0.1833
# Epoch 7/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.2931 - accuracy: 0.1700
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.2246 - accuracy: 0.1600
# Epoch 9/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.1816 - accuracy: 0.1833
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.1616 - accuracy: 0.1933
# loaded 2400 to 2700
# Epoch 1/10
# 6/6 [==============================] - 0s 45ms/step - loss: 5.5221 - accuracy: 0.1333
# Epoch 2/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3236 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1775 - accuracy: 0.1467
# Epoch 4/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.1948 - accuracy: 0.1500
# Epoch 5/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.0622 - accuracy: 0.1500
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.1644 - accuracy: 0.1467
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.2687 - accuracy: 0.1333
# Epoch 8/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3485 - accuracy: 0.1267
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1831 - accuracy: 0.1500
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9912 - accuracy: 0.1233
# Epoch 1/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.3811 - accuracy: 0.1500
# Epoch 2/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.3373 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2124 - accuracy: 0.1467
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.7695 - accuracy: 0.1200
# Epoch 5/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3434 - accuracy: 0.1433
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2276 - accuracy: 0.1500
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2377 - accuracy: 0.1467
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.1049 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 29ms/step - loss: 1.3631 - accuracy: 0.1333
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.1814 - accuracy: 0.1433
# Epoch 1/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.6951 - accuracy: 0.1500
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.4772 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 66ms/step - loss: 1.3816 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.4235 - accuracy: 0.1467
# Epoch 5/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.3720 - accuracy: 0.1433
# Epoch 6/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.3962 - accuracy: 0.1433
# Epoch 7/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.2850 - accuracy: 0.1433
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.2185 - accuracy: 0.1500
# Epoch 9/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.3229 - accuracy: 0.1400
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.3138 - accuracy: 0.1467
# loaded 2700 to 3000
# Epoch 1/10
# 6/6 [==============================] - 0s 40ms/step - loss: 2.5498 - accuracy: 0.1133
# Epoch 2/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.5864 - accuracy: 0.1033
# Epoch 3/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3050 - accuracy: 0.1133
# Epoch 4/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3718 - accuracy: 0.1167
# Epoch 5/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.8982 - accuracy: 0.1067
# Epoch 6/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.6389 - accuracy: 0.1100
# Epoch 7/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.2529 - accuracy: 0.1100
# Epoch 8/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.5973 - accuracy: 0.1167
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.3500 - accuracy: 0.1033
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 3.0432 - accuracy: 0.1100
# Epoch 1/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.5577 - accuracy: 0.1167
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.7137 - accuracy: 0.1200
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.4741 - accuracy: 0.1133
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.4818 - accuracy: 0.1033
# Epoch 5/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2525 - accuracy: 0.1200
# Epoch 6/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.5593 - accuracy: 0.1133
# Epoch 7/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.1974 - accuracy: 0.1200
# Epoch 8/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.0732 - accuracy: 0.1200
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3917 - accuracy: 0.1200
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 5.0551 - accuracy: 0.1200
# Epoch 1/10
# 6/6 [==============================] - 0s 66ms/step - loss: 1.5042 - accuracy: 0.1200
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.4863 - accuracy: 0.1167
# Epoch 3/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.5022 - accuracy: 0.1167
# Epoch 4/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.3713 - accuracy: 0.1200
# Epoch 5/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.3745 - accuracy: 0.1200
# Epoch 6/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.2553 - accuracy: 0.1200
# Epoch 7/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.2162 - accuracy: 0.1167
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.1364 - accuracy: 0.1167
# Epoch 9/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.1430 - accuracy: 0.1200
# Epoch 10/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.1090 - accuracy: 0.1200
# loaded 3000 to 3300
# Epoch 1/10
# 6/6 [==============================] - 0s 42ms/step - loss: 1.4092 - accuracy: 0.1967
# Epoch 2/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.2321 - accuracy: 0.2000
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.0477 - accuracy: 0.2033
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.7068 - accuracy: 0.1733
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.2449 - accuracy: 0.1767
# Epoch 6/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.4905 - accuracy: 0.1800
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3697 - accuracy: 0.1733
# Epoch 8/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0662 - accuracy: 0.1767
# Epoch 9/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9784 - accuracy: 0.1967
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.5860 - accuracy: 0.1633
# Epoch 1/10
# 6/6 [==============================] - 0s 32ms/step - loss: 2.9725 - accuracy: 0.2000
# Epoch 2/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.4045 - accuracy: 0.1900
# Epoch 3/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.2911 - accuracy: 0.1933
# Epoch 4/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.4046 - accuracy: 0.1933
# Epoch 5/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.2281 - accuracy: 0.1967
# Epoch 6/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.3231 - accuracy: 0.2033
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2140 - accuracy: 0.2000
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.0189 - accuracy: 0.2033
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.4906 - accuracy: 0.1967
# Epoch 10/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.1600 - accuracy: 0.1967
# Epoch 1/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.4915 - accuracy: 0.2033
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.3815 - accuracy: 0.0867
# Epoch 3/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.3383 - accuracy: 0.0800
# Epoch 4/10
# 6/6 [==============================] - 0s 62ms/step - loss: 1.1264 - accuracy: 0.2000
# Epoch 5/10
# 6/6 [==============================] - 0s 62ms/step - loss: 1.0831 - accuracy: 0.1967
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.9894 - accuracy: 0.1767
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.9016 - accuracy: 0.2033
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 0.8647 - accuracy: 0.1967
# Epoch 9/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.7959 - accuracy: 0.1900
# Epoch 10/10
# 6/6 [==============================] - 0s 64ms/step - loss: 0.9223 - accuracy: 0.2000
# loaded 3300 to 3600
# Epoch 1/10
# 6/6 [==============================] - 0s 44ms/step - loss: 1.3207 - accuracy: 0.1533
# Epoch 2/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.2310 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.2359 - accuracy: 0.1533
# Epoch 4/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.1570 - accuracy: 0.1533
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.5038 - accuracy: 0.1333
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3327 - accuracy: 0.1167
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9202 - accuracy: 0.1567
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1818 - accuracy: 0.1433
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1551 - accuracy: 0.1467
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9468 - accuracy: 0.1467
# Epoch 1/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.3786 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.1572 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.3038 - accuracy: 0.1567
# Epoch 4/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.6696 - accuracy: 0.1467
# Epoch 5/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.0316 - accuracy: 0.1567
# Epoch 6/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.1542 - accuracy: 0.1567
# Epoch 7/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.1153 - accuracy: 0.1533
# Epoch 8/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.0582 - accuracy: 0.1567
# Epoch 9/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.1697 - accuracy: 0.1567
# Epoch 10/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.9903 - accuracy: 0.1567
# Epoch 1/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.2553 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 61ms/step - loss: 1.1721 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 66ms/step - loss: 1.0768 - accuracy: 0.1467
# Epoch 4/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.1203 - accuracy: 0.1533
# Epoch 5/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.1018 - accuracy: 0.1567
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.2891 - accuracy: 0.1567
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.1328 - accuracy: 0.1567
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.1635 - accuracy: 0.1567
# Epoch 9/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.1681 - accuracy: 0.1567
# Epoch 10/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.0068 - accuracy: 0.1567
# loaded 3600 to 3900
# Epoch 1/10
# 6/6 [==============================] - 0s 47ms/step - loss: 1.9706 - accuracy: 0.1233
# Epoch 2/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.4758 - accuracy: 0.1267
# Epoch 3/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.3097 - accuracy: 0.1667
# Epoch 4/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3011 - accuracy: 0.1667
# Epoch 5/10
# 6/6 [==============================] - 0s 35ms/step - loss: 1.6373 - accuracy: 0.1300
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.1947 - accuracy: 0.1433
# Epoch 7/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.2379 - accuracy: 0.1333
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.9329 - accuracy: 0.1667
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.3317 - accuracy: 0.1333
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.5383 - accuracy: 0.1667
# Epoch 1/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.5717 - accuracy: 0.1633
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.5904 - accuracy: 0.1633
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.5243 - accuracy: 0.1700
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2952 - accuracy: 0.1633
# Epoch 5/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.4462 - accuracy: 0.1533
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3118 - accuracy: 0.1667
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.1495 - accuracy: 0.1700
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.1967 - accuracy: 0.1667
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3694 - accuracy: 0.1600
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2892 - accuracy: 0.1667
# Epoch 1/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.3839 - accuracy: 0.1600
# Epoch 2/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.3081 - accuracy: 0.1700
# Epoch 3/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.4372 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.7943 - accuracy: 0.1333
# Epoch 5/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.4073 - accuracy: 0.1700
# Epoch 6/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.3370 - accuracy: 0.1700
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.0946 - accuracy: 0.1700
# Epoch 8/10
# 6/6 [==============================] - 0s 66ms/step - loss: 1.0245 - accuracy: 0.1667
# Epoch 9/10
# 6/6 [==============================] - 0s 64ms/step - loss: 0.9378 - accuracy: 0.1700
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.9048 - accuracy: 0.1700
# loaded 3900 to 4200
# Epoch 1/10
# 6/6 [==============================] - 0s 46ms/step - loss: 1.3541 - accuracy: 0.1633
# Epoch 2/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.6880 - accuracy: 0.1633
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.2788 - accuracy: 0.1700
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1451 - accuracy: 0.1667
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.1564 - accuracy: 0.1700
# Epoch 6/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.4395 - accuracy: 0.1367
# Epoch 7/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.3187 - accuracy: 0.1600
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.6676 - accuracy: 0.1333
# Epoch 9/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.9911 - accuracy: 0.1700
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0938 - accuracy: 0.1467
# Epoch 1/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.5744 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.3178 - accuracy: 0.1700
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3364 - accuracy: 0.1700
# Epoch 4/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.5805 - accuracy: 0.1533
# Epoch 5/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3032 - accuracy: 0.1700
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.0658 - accuracy: 0.1700
# Epoch 7/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.2647 - accuracy: 0.1700
# Epoch 8/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.0828 - accuracy: 0.1633
# Epoch 9/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.4199 - accuracy: 0.1467
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.1226 - accuracy: 0.1700
# Epoch 1/10
# 6/6 [==============================] - 0s 67ms/step - loss: 1.2608 - accuracy: 0.1700
# Epoch 2/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.2614 - accuracy: 0.1700
# Epoch 3/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.1270 - accuracy: 0.1667
# Epoch 4/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.1467 - accuracy: 0.1700
# Epoch 5/10
# 6/6 [==============================] - 0s 62ms/step - loss: 1.1441 - accuracy: 0.1600
# Epoch 6/10
# 6/6 [==============================] - 0s 64ms/step - loss: 0.9567 - accuracy: 0.1633
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.9300 - accuracy: 0.1700
# Epoch 8/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.9822 - accuracy: 0.1700
# Epoch 9/10
# 6/6 [==============================] - 0s 64ms/step - loss: 0.9350 - accuracy: 0.1700
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.8507 - accuracy: 0.1700
# loaded 4200 to 4500
# Epoch 1/10
# 6/6 [==============================] - 0s 44ms/step - loss: 1.8405 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.5303 - accuracy: 0.1533
# Epoch 3/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.6142 - accuracy: 0.1433
# Epoch 4/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.3038 - accuracy: 0.1533
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 8.4108 - accuracy: 0.0833
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.3136 - accuracy: 0.1500
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.2249 - accuracy: 0.1433
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.2277 - accuracy: 0.1400
# Epoch 9/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0978 - accuracy: 0.1467
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0268 - accuracy: 0.1400
# Epoch 1/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.6343 - accuracy: 0.1533
# Epoch 2/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.6120 - accuracy: 0.1533
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.3834 - accuracy: 0.1433
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 2.0004 - accuracy: 0.1367
# Epoch 5/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2930 - accuracy: 0.1367
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.5104 - accuracy: 0.1533
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.2257 - accuracy: 0.1533
# Epoch 8/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.3239 - accuracy: 0.1467
# Epoch 9/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.3511 - accuracy: 0.1500
# Epoch 10/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.2535 - accuracy: 0.1500
# Epoch 1/10
# 6/6 [==============================] - 0s 67ms/step - loss: 1.4320 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.3149 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.2632 - accuracy: 0.1533
# Epoch 4/10
# 6/6 [==============================] - 0s 63ms/step - loss: 1.2437 - accuracy: 0.1533
# Epoch 5/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.1946 - accuracy: 0.1533
# Epoch 6/10
# 6/6 [==============================] - 0s 64ms/step - loss: 1.0514 - accuracy: 0.1533
# Epoch 7/10
# 6/6 [==============================] - 0s 64ms/step - loss: 0.9633 - accuracy: 0.1567
# Epoch 8/10
# 6/6 [==============================] - 0s 66ms/step - loss: 1.0035 - accuracy: 0.1567
# Epoch 9/10
# 6/6 [==============================] - 0s 65ms/step - loss: 1.0617 - accuracy: 0.1567
# Epoch 10/10
# 6/6 [==============================] - 0s 65ms/step - loss: 0.8754 - accuracy: 0.1567
# loaded 4500 to 4800
# Epoch 1/10
# 6/6 [==============================] - 0s 45ms/step - loss: 1.5970 - accuracy: 0.1267
# Epoch 2/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.2708 - accuracy: 0.1500
# Epoch 3/10
# 6/6 [==============================] - 0s 35ms/step - loss: 1.2713 - accuracy: 0.1467
# Epoch 4/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0408 - accuracy: 0.1433
# Epoch 5/10
# 6/6 [==============================] - 0s 35ms/step - loss: 1.7414 - accuracy: 0.1433
# Epoch 6/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.9400 - accuracy: 0.1567
# Epoch 7/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.9930 - accuracy: 0.1367
# Epoch 8/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.5371 - accuracy: 0.1200
# Epoch 9/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.1868 - accuracy: 0.1467
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0301 - accuracy: 0.1333
# Epoch 1/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.8922 - accuracy: 0.1500
# Epoch 2/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.1550 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.2596 - accuracy: 0.1567
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.5124 - accuracy: 0.1233
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.1012 - accuracy: 0.1567
# Epoch 6/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1293 - accuracy: 0.1567
# Epoch 7/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.2262 - accuracy: 0.1400
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.1623 - accuracy: 0.1533
# Epoch 9/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.1350 - accuracy: 0.1533
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.3820 - accuracy: 0.1533
# Epoch 1/10
# 6/6 [==============================] - 0s 67ms/step - loss: 1.1289 - accuracy: 0.1567
# Epoch 2/10
# 6/6 [==============================] - 0s 66ms/step - loss: 1.0355 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 65ms/step - loss: 0.9819 - accuracy: 0.1567
# Epoch 4/10
# 6/6 [==============================] - 0s 64ms/step - loss: 0.9126 - accuracy: 0.1533
# Epoch 5/10
# 6/6 [==============================] - 0s 64ms/step - loss: 0.9668 - accuracy: 0.1533
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.9231 - accuracy: 0.1400
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.8987 - accuracy: 0.1567
# Epoch 8/10
# 6/6 [==============================] - 0s 63ms/step - loss: 0.9909 - accuracy: 0.1567
# Epoch 9/10
# 6/6 [==============================] - 0s 64ms/step - loss: 0.9787 - accuracy: 0.1533
# Epoch 10/10
# 6/6 [==============================] - 0s 65ms/step - loss: 0.9635 - accuracy: 0.1433
# loaded 4800 to 5100
# Epoch 1/10
# 6/6 [==============================] - 0s 43ms/step - loss: 1.3022 - accuracy: 0.1500
# Epoch 2/10
# 6/6 [==============================] - 0s 36ms/step - loss: 1.2984 - accuracy: 0.1400
# Epoch 3/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.1910 - accuracy: 0.1600
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1574 - accuracy: 0.1533
# Epoch 5/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.0191 - accuracy: 0.1467
# Epoch 6/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.7635 - accuracy: 0.1500
# Epoch 7/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.2198 - accuracy: 0.1633
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1754 - accuracy: 0.1533
# Epoch 9/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9337 - accuracy: 0.1700
# Epoch 10/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.2499 - accuracy: 0.1600
# Epoch 1/10
# ...
# Epoch 8/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.1926 - accuracy: 0.1400
# Epoch 9/10
# 6/6 [==============================] - 0s 30ms/step - loss: 0.8529 - accuracy: 0.1433
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 0.8990 - accuracy: 0.1400
# Epoch 1/10
# 6/6 [==============================] - 0s 62ms/step - loss: 9.1402 - accuracy: 0.1433
# Epoch 2/10
# 6/6 [==============================] - 0s 61ms/step - loss: 8.9787 - accuracy: 0.1433
# Epoch 3/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.6536 - accuracy: 0.1433
# Epoch 4/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.6736 - accuracy: 0.1433
# Epoch 5/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.5545 - accuracy: 0.1433
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.6323 - accuracy: 0.1433
# Epoch 7/10
# 6/6 [==============================] - 0s 61ms/step - loss: 8.5552 - accuracy: 0.1433
# Epoch 8/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.5627 - accuracy: 0.1433
# Epoch 9/10
# 6/6 [==============================] - 0s 64ms/step - loss: 8.5379 - accuracy: 0.1433
# Epoch 10/10
# 6/6 [==============================] - 0s 65ms/step - loss: 8.5593 - accuracy: 0.1433
# loaded 10800 to 11100
# Epoch 1/10
# 6/6 [==============================] - 0s 47ms/step - loss: 1.7170 - accuracy: 0.1400
# Epoch 2/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.3988 - accuracy: 0.1533
# Epoch 3/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.2977 - accuracy: 0.1500
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1381 - accuracy: 0.1567
# Epoch 5/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.1794 - accuracy: 0.1633
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9374 - accuracy: 0.1600
# Epoch 7/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.1037 - accuracy: 0.1667
# Epoch 8/10
# 6/6 [==============================] - 0s 33ms/step - loss: 5.6870 - accuracy: 0.1300
# Epoch 9/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.9352 - accuracy: 0.1600
# Epoch 10/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.8725 - accuracy: 0.1533
# Epoch 1/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.0378 - accuracy: 0.1700
# Epoch 2/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.9310 - accuracy: 0.1700
# Epoch 3/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.1189 - accuracy: 0.1700
# Epoch 4/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.1021 - accuracy: 0.1700
# Epoch 5/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.2322 - accuracy: 0.1700
# Epoch 6/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.2285 - accuracy: 0.1700
# Epoch 7/10
# 6/6 [==============================] - 0s 30ms/step - loss: 0.8823 - accuracy: 0.1700
# Epoch 8/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.8887 - accuracy: 0.1700
# Epoch 9/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.8235 - accuracy: 0.1700
# Epoch 10/10
# 6/6 [==============================] - 0s 30ms/step - loss: 0.9527 - accuracy: 0.1700
# Epoch 1/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.7032 - accuracy: 0.1700
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.6950 - accuracy: 0.1700
# Epoch 3/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.6827 - accuracy: 0.1700
# Epoch 4/10
# 6/6 [==============================] - 0s 65ms/step - loss: 8.6699 - accuracy: 0.1700
# Epoch 5/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.6445 - accuracy: 0.1700
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.6211 - accuracy: 0.1700
# Epoch 7/10
# 6/6 [==============================] - 0s 64ms/step - loss: 8.6135 - accuracy: 0.1700
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 8.5839 - accuracy: 0.1700
# Epoch 9/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.5633 - accuracy: 0.1700
# Epoch 10/10
# 6/6 [==============================] - 0s 61ms/step - loss: 8.5555 - accuracy: 0.1700
# loaded 11100 to 11400
# Epoch 1/10
# 6/6 [==============================] - 0s 42ms/step - loss: 1.1332 - accuracy: 0.1700
# Epoch 2/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.9853 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.1978 - accuracy: 0.1400
# Epoch 4/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.8312 - accuracy: 0.1700
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.5387 - accuracy: 0.1267
# Epoch 6/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9615 - accuracy: 0.1733
# Epoch 7/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.7611 - accuracy: 0.1767
# Epoch 8/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.8261 - accuracy: 0.1733
# Epoch 9/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.8630 - accuracy: 0.1667
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.8870 - accuracy: 0.1600
# Epoch 1/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.0942 - accuracy: 0.1800
# Epoch 2/10
# 6/6 [==============================] - 0s 30ms/step - loss: 0.9976 - accuracy: 0.1800
# Epoch 3/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.4214 - accuracy: 0.1800
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 1.0328 - accuracy: 0.1800
# Epoch 5/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.0875 - accuracy: 0.1800
# Epoch 6/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.9960 - accuracy: 0.1767
# Epoch 7/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.8288 - accuracy: 0.1800
# Epoch 8/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.2409 - accuracy: 0.1800
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.9608 - accuracy: 0.1800
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.9758 - accuracy: 0.1800
# Epoch 1/10
# 6/6 [==============================] - 0s 64ms/step - loss: 8.0229 - accuracy: 0.1800
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.0239 - accuracy: 0.1800
# Epoch 3/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.0330 - accuracy: 0.1800
# Epoch 4/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.0195 - accuracy: 0.1800
# Epoch 5/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.0211 - accuracy: 0.1800
# Epoch 6/10
# 6/6 [==============================] - 0s 61ms/step - loss: 8.0224 - accuracy: 0.1800
# Epoch 7/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.0192 - accuracy: 0.1800
# Epoch 8/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.0222 - accuracy: 0.1800
# Epoch 9/10
# 6/6 [==============================] - 0s 65ms/step - loss: 8.0188 - accuracy: 0.1800
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.0216 - accuracy: 0.1800
# loaded 11400 to 11700
# Epoch 1/10
# 6/6 [==============================] - 0s 42ms/step - loss: 4.3493 - accuracy: 0.1400
# Epoch 2/10
# 6/6 [==============================] - 0s 35ms/step - loss: 1.0084 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.9094 - accuracy: 0.1667
# Epoch 4/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.9568 - accuracy: 0.1533
# Epoch 5/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.8679 - accuracy: 0.1667
# Epoch 6/10
# 6/6 [==============================] - 0s 36ms/step - loss: 0.7749 - accuracy: 0.1467
# Epoch 7/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.1275 - accuracy: 0.1367
# Epoch 8/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.8438 - accuracy: 0.1400
# Epoch 9/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0634 - accuracy: 0.1633
# Epoch 10/10
# 6/6 [==============================] - 0s 34ms/step - loss: 1.3754 - accuracy: 0.1633
# Epoch 1/10
# 6/6 [==============================] - 0s 31ms/step - loss: 1.0242 - accuracy: 0.1667
# Epoch 2/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.9041 - accuracy: 0.1667
# Epoch 3/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.8957 - accuracy: 0.1600
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 0.8555 - accuracy: 0.1667
# Epoch 5/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.0042 - accuracy: 0.1667
# Epoch 6/10
# 6/6 [==============================] - 0s 30ms/step - loss: 0.7232 - accuracy: 0.1667
# Epoch 7/10
# 6/6 [==============================] - 0s 33ms/step - loss: 0.7930 - accuracy: 0.1633
# Epoch 8/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.9788 - accuracy: 0.1667
# Epoch 9/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.7427 - accuracy: 0.1667
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.6568 - accuracy: 0.1667
# Epoch 1/10
# 6/6 [==============================] - 0s 64ms/step - loss: 7.6354 - accuracy: 0.1667
# Epoch 2/10
# 6/6 [==============================] - 0s 62ms/step - loss: 7.6355 - accuracy: 0.1667
# Epoch 3/10
# 6/6 [==============================] - 0s 64ms/step - loss: 7.6364 - accuracy: 0.1667
# Epoch 4/10
# 6/6 [==============================] - 0s 64ms/step - loss: 7.6372 - accuracy: 0.1667
# Epoch 5/10
# 6/6 [==============================] - 0s 64ms/step - loss: 7.6387 - accuracy: 0.1667
# Epoch 6/10
# 6/6 [==============================] - 0s 66ms/step - loss: 7.6367 - accuracy: 0.1667
# Epoch 7/10
# 6/6 [==============================] - 0s 64ms/step - loss: 7.6359 - accuracy: 0.1667
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 7.6358 - accuracy: 0.1667
# Epoch 9/10
# 6/6 [==============================] - 0s 62ms/step - loss: 7.6349 - accuracy: 0.1667
# Epoch 10/10
# 6/6 [==============================] - 0s 61ms/step - loss: 7.6342 - accuracy: 0.1667
# loaded 11700 to 12000
# Epoch 1/10
# 6/6 [==============================] - 0s 44ms/step - loss: 1.0121 - accuracy: 0.1800
# Epoch 2/10
# 6/6 [==============================] - 0s 35ms/step - loss: 1.2621 - accuracy: 0.1567
# Epoch 3/10
# 6/6 [==============================] - 0s 35ms/step - loss: 1.0687 - accuracy: 0.1867
# Epoch 4/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.9088 - accuracy: 0.1867
# Epoch 5/10
# 6/6 [==============================] - 0s 35ms/step - loss: 0.9840 - accuracy: 0.1567
# Epoch 6/10
# 6/6 [==============================] - 0s 35ms/step - loss: 1.0988 - accuracy: 0.1600
# Epoch 7/10
# 6/6 [==============================] - 0s 36ms/step - loss: 0.7686 - accuracy: 0.1867
# Epoch 8/10
# 6/6 [==============================] - 0s 34ms/step - loss: 0.9669 - accuracy: 0.1367
# Epoch 9/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0393 - accuracy: 0.1400
# Epoch 10/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.0385 - accuracy: 0.1867
# Epoch 1/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.0926 - accuracy: 0.1867
# Epoch 2/10
# 6/6 [==============================] - 0s 32ms/step - loss: 1.0081 - accuracy: 0.1867
# Epoch 3/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.9041 - accuracy: 0.1867
# Epoch 4/10
# 6/6 [==============================] - 0s 30ms/step - loss: 0.8072 - accuracy: 0.1867
# Epoch 5/10
# 6/6 [==============================] - 0s 33ms/step - loss: 1.0204 - accuracy: 0.1833
# Epoch 6/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.8288 - accuracy: 0.1867
# Epoch 7/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.8086 - accuracy: 0.1867
# Epoch 8/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.8684 - accuracy: 0.1867
# Epoch 9/10
# 6/6 [==============================] - 0s 32ms/step - loss: 0.9025 - accuracy: 0.1867
# Epoch 10/10
# 6/6 [==============================] - 0s 31ms/step - loss: 0.9856 - accuracy: 0.1867
# Epoch 1/10
# 6/6 [==============================] - 0s 65ms/step - loss: 8.5358 - accuracy: 0.1867
# Epoch 2/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.5320 - accuracy: 0.1867
# Epoch 3/10
# 6/6 [==============================] - 0s 65ms/step - loss: 8.5200 - accuracy: 0.1867
# Epoch 4/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.5032 - accuracy: 0.1867
# Epoch 5/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.4928 - accuracy: 0.1867
# Epoch 6/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.4741 - accuracy: 0.1867
# Epoch 7/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.4623 - accuracy: 0.1867
# Epoch 8/10
# 6/6 [==============================] - 0s 64ms/step - loss: 8.4318 - accuracy: 0.1867
# Epoch 9/10
# 6/6 [==============================] - 0s 62ms/step - loss: 8.4004 - accuracy: 0.1867
# Epoch 10/10
# 6/6 [==============================] - 0s 63ms/step - loss: 8.3918 - accuracy: 0.1867
# loaded 12000 to 12050
# Epoch 1/10
# 1/1 [==============================] - 0s 34ms/step - loss: 1.5033 - accuracy: 0.2600
# Epoch 2/10
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2618 - accuracy: 0.2600
# Epoch 3/10
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0476 - accuracy: 0.2600
# Epoch 4/10
# 1/1 [==============================] - 0s 33ms/step - loss: 0.9264 - accuracy: 0.2600
# Epoch 5/10
# 1/1 [==============================] - 0s 35ms/step - loss: 0.8638 - accuracy: 0.2600
# Epoch 6/10
# 1/1 [==============================] - 0s 36ms/step - loss: 1.0916 - accuracy: 0.2400
# Epoch 7/10
# 1/1 [==============================] - 0s 35ms/step - loss: 1.1650 - accuracy: 0.2600
# Epoch 8/10
# 1/1 [==============================] - 0s 35ms/step - loss: 0.6936 - accuracy: 0.2600
# Epoch 9/10
# 1/1 [==============================] - 0s 44ms/step - loss: 0.6637 - accuracy: 0.2600
# Epoch 10/10
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6938 - accuracy: 0.2400
# Epoch 1/10
# 1/1 [==============================] - 0s 33ms/step - loss: 1.2602 - accuracy: 0.2600
# Epoch 2/10
# 1/1 [==============================] - 0s 32ms/step - loss: 1.1036 - accuracy: 0.2600
# Epoch 3/10
# 1/1 [==============================] - 0s 32ms/step - loss: 0.9155 - accuracy: 0.2600
# Epoch 4/10
# 1/1 [==============================] - 0s 30ms/step - loss: 0.9257 - accuracy: 0.2600
# Epoch 5/10
# 1/1 [==============================] - 0s 37ms/step - loss: 0.8628 - accuracy: 0.2600
# Epoch 6/10
# 1/1 [==============================] - 0s 32ms/step - loss: 0.8893 - accuracy: 0.2600
# Epoch 7/10
# 1/1 [==============================] - 0s 36ms/step - loss: 0.8477 - accuracy: 0.2600
# Epoch 8/10
# 1/1 [==============================] - 0s 34ms/step - loss: 1.0001 - accuracy: 0.2600
# Epoch 9/10
# 1/1 [==============================] - 0s 38ms/step - loss: 1.0322 - accuracy: 0.2600
# Epoch 10/10
# 1/1 [==============================] - 0s 33ms/step - loss: 3.8407 - accuracy: 0.0000e+00
# Epoch 1/10
# 1/1 [==============================] - 0s 62ms/step - loss: 8.2005 - accuracy: 0.2600
# Epoch 2/10
# 1/1 [==============================] - 0s 64ms/step - loss: 8.1806 - accuracy: 0.2600
# Epoch 3/10
# 1/1 [==============================] - 0s 64ms/step - loss: 8.1557 - accuracy: 0.2600
# Epoch 4/10
# 1/1 [==============================] - 0s 62ms/step - loss: 8.1266 - accuracy: 0.2600
# Epoch 5/10
# 1/1 [==============================] - 0s 63ms/step - loss: 8.0938 - accuracy: 0.2600
# Epoch 6/10
# 1/1 [==============================] - 0s 62ms/step - loss: 8.0580 - accuracy: 0.2600
# Epoch 7/10
# 1/1 [==============================] - 0s 61ms/step - loss: 8.0197 - accuracy: 0.2600
# Epoch 8/10
# 1/1 [==============================] - 0s 62ms/step - loss: 7.9794 - accuracy: 0.2600
# Epoch 9/10
# 1/1 [==============================] - 0s 62ms/step - loss: 7.9376 - accuracy: 0.2600
# Epoch 10/10
# 1/1 [==============================] - 0s 60ms/step - loss: 7.8947 - accuracy: 0.2600

# %%
# treina o modelo usando batches de 300 imagens por vez

for i in range(ceil(len(X_train)/img_to_load)):
#for i in range(ceil(1500/img_to_load)):
    begin = i*img_to_load
    limit = min(i*img_to_load + img_to_load, len(X_train))
    if begin == limit:
        break

    X_train_img = [crop_center(imread(file), crop_size, crop_size) for file in X_train[begin:limit]]
    Y_train_img = Y_train[begin:limit]
    print(f'loaded {begin} to {limit}')

    X_train_img = np.stack(X_train_img, axis=0)
    X_train_img = X_train_img.reshape((X_train_img.shape + (1,)))
    Y_train_img = np.stack(Y_train_img, axis=0).reshape((len(Y_train_img), 1))
    #print(X_train_img.shape)
    third_model.fit(X_train_img, Y_train_img, epochs=10, batch_size=50)

# %%
# gera um arquivo com os pesos do modelo

#test_model.save('saved_test_model')
# Out:
# INFO:tensorflow:Assets written to: saved_test_model/assets

# %%
# usar se estiver usando google colab, isso gera um zip e faz o download do modelo

#!zip -r saved_test_model.zip saved_test_model
#files.download('saved_test_model.zip')
# Out:
#   adding: saved_test_model/ (stored 0%)
#   adding: saved_test_model/variables/ (stored 0%)
#   adding: saved_test_model/variables/variables.data-00000-of-00001 (deflated 47%)
#   adding: saved_test_model/variables/variables.index (deflated 69%)
#   adding: saved_test_model/assets/ (stored 0%)
#   adding: saved_test_model/saved_model.pb (deflated 90%)

# %%
# usar se estiver usando google colab, isso descompacta um arquivo no diretório do notebook

#!unzip saved_test_model.zip

# %%
# carrega um modelo salvo anteriormente

test = load_model('saved_test_model')

# %%
# carrega as 1000 primeiras imagens usadas para testar

X_test_img = [crop_center(imread(file), crop_size, crop_size) for file in X_test[:1000]]
print(f'loaded test images')
Y_test_img = Y_test[:1000]
X_test_img = np.stack(X_test_img, axis=0)
X_test_img = X_test_img.reshape((X_test_img.shape + (1,)))
Y_test_img = np.stack(Y_test_img, axis=0).reshape((len(Y_test_img), 1))
# Out:
# loaded test images

# %%
# valida o modelo
#test = modelo carregado
preds = test_model.evaluate(X_test_img, Y_test_img, batch_size=32, verbose=1, sample_weight=None)

print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 32/32 [==============================] - 1s 10ms/step - loss: 0.0070 - accuracy: 0.1660
#
# Loss = 0.0070226178504526615
# Test Accuracy = 0.16599999368190765

# %%
# valida o modelo
#test = modelo carregado
preds = second_model.evaluate(X_test_img, Y_test_img, batch_size=32, verbose=1, sample_weight=None)

print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 32/32 [==============================] - 0s 10ms/step - loss: 11.8352 - accuracy: 0.1660
#
# Loss = 11.835211753845215
# Test Accuracy = 0.16599999368190765

# %%
# valida o modelo
#test = modelo carregado
preds = third_model.evaluate(X_test_img, Y_test_img, batch_size=32, verbose=1, sample_weight=None)

print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 32/32 [==============================] - 0s 8ms/step - loss: 12.0839 - accuracy: 0.1660
#
# Loss = 12.08386516571045
# Test Accuracy = 0.16599999368190765

# %%
# valida o modelo
#test = modelo carregado
preds = fourth_model.evaluate(X_test_img, Y_test_img, batch_size=32, verbose=1, sample_weight=None)

print()
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 32/32 [==============================] - 0s 13ms/step - loss: 7.3074 - accuracy: 0.1660
#
# Loss = 7.307413101196289
# Test Accuracy = 0.16599999368190765
